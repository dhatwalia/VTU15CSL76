# %% [markdown]
# # 7.Problem : Write a program to construct a Bayesian network considering medical data. Use this model to demonstrate the diagnosis of heart patients using standard Heart Disease Data Set. You can use Python ML library API.

# %%
# Starting with defining the network structure
from pgmpy.models import BayesianModel

cancer_model = BayesianModel([('Pollution', 'Cancer'), ('Smoker', 'Cancer'),
                              ('Cancer', 'Xray'),('Cancer', 'Dyspnoea')])

# %%
print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
# Now defining the parameters.
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,
                      values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,
                       values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],
                                [0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'], evidence_card=[2])

# %%
# Associating the parameters with the model structure.
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)

# Checking if the cpds are valid for the model.
cancer_model.check_model()
# Out:
# True

# %%
# Doing some simple queries on the network
cancer_model.is_active_trail('Pollution', 'Smoker')
# Out:
# False

# %%
cancer_model.is_active_trail('Pollution', 'Smoker', observed=['Cancer'])
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x7f9747fea898>,
#  <TabularCPD representing P(Smoker:2) at 0x7f9747fea860>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x7f9747fea908>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x7f9747fea940>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x7f9747fea978>]

# %%
print(cancer_model.get_cpds('Pollution'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛

# %%
print(cancer_model.get_cpds('Smoker'))
# Out:
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛

# %%
print(cancer_model.get_cpds('Xray'))
# Out:
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Dyspnoea'))
# Out:
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛

# %%
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %%
cancer_model.local_independencies('Xray')
# Out:
# (Xray _|_ Pollution, Smoker, Dyspnoea | Cancer)

# %%
cancer_model.local_independencies('Pollution')
# Out:
# (Pollution _|_ Smoker, Xray, Cancer, Dyspnoea)

# %%
cancer_model.local_independencies('Smoker')
# Out:
# (Smoker _|_ Pollution, Xray, Cancer, Dyspnoea)

# %%
cancer_model.local_independencies('Dyspnoea')
# Out:
# (Dyspnoea _|_ Xray, Smoker, Pollution | Cancer)

# %%
cancer_model.local_independencies('Cancer')
# Out:
# (Cancer _|_ Xray, Dyspnoea | Pollution, Smoker)

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Xray, Dyspnoea | Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Xray, Cancer)
# (Pollution _|_ Xray | Cancer, Dyspnoea)
# (Pollution _|_ Dyspnoea | Cancer, Xray, Smoker)
# (Pollution _|_ Xray | Cancer, Smoker, Dyspnoea)
# (Smoker _|_ Pollution)
# (Smoker _|_ Xray, Dyspnoea | Cancer)
# (Smoker _|_ Xray, Dyspnoea | Pollution, Cancer)
# (Smoker _|_ Dyspnoea | Xray, Cancer)
# (Smoker _|_ Xray | Cancer, Dyspnoea)
# (Smoker _|_ Dyspnoea | Pollution, Xray, Cancer)
# (Smoker _|_ Xray | Pollution, Cancer, Dyspnoea)
# (Xray _|_ Pollution, Smoker, Dyspnoea | Cancer)
# (Xray _|_ Pollution, Dyspnoea | Cancer, Smoker)
# (Xray _|_ Smoker, Dyspnoea | Cancer, Pollution)
# (Xray _|_ Pollution, Smoker | Cancer, Dyspnoea)
# (Xray _|_ Dyspnoea | Cancer, Smoker, Pollution)
# (Xray _|_ Pollution | Cancer, Smoker, Dyspnoea)
# (Xray _|_ Smoker | Dyspnoea, Cancer, Pollution)
# (Dyspnoea _|_ Xray, Smoker, Pollution | Cancer)
# (Dyspnoea _|_ Xray, Pollution | Cancer, Smoker)
# (Dyspnoea _|_ Pollution, Smoker | Xray, Cancer)
# (Dyspnoea _|_ Xray, Smoker | Cancer, Pollution)
# (Dyspnoea _|_ Pollution | Cancer, Xray, Smoker)
# (Dyspnoea _|_ Xray | Cancer, Smoker, Pollution)
# (Dyspnoea _|_ Smoker | Xray, Cancer, Pollution)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan) #see a whole array when we output it

names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 
         'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  heartdisease
# 0    ?             0
# 1    ?             0
# 2    ?             0
# 3    6             0
# 4    ?             0

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)
heartDisease.dtypes
# Out:
# age              int64
# sex              int64
# cp               int64
# trestbps        object
# chol            object
# fbs             object
# restecg         object
# thalach         object
# exang           object
# heartdisease     int64
# dtype: object

# %%
heartDisease.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  heartdisease
# 0   28    1   2      130  132   0       2     185     0             0
# 1   29    1   2      120  243   0       0     160     0             0
# 2   29    1   2      140  NaN   0       0     170     0             0
# 3   30    0   1      170  237   0       1     170     0             0
# 4   31    0   2      100  219   0       1     150     0             0

# %%
heartDisease.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'heartdisease'],
#       dtype='object')

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
 #   print("CPD of {variable}:".format(variable=cpd.variable))
  #  print(cpd)

# %%
print(model.get_cpds('age'))
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛

# %%
print(model.get_cpds('chol'))
# Out:
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.006535947712418301 │ 0.006535947712418301 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006535947712418301 │ 0.006535947712418301 │
# ╘══════════════╧══════════════════════╧══════════════════════╛

# %%
print(model.get_cpds('sex'))
# Out:
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛

# %%
model.get_independencies()
# Out:
# (age _|_ sex, exang)
# (age _|_ exang | sex)
# (age _|_ sex, exang | fbs)
# (age _|_ sex | exang)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ exang | sex, fbs)
# (age _|_ restecg, chol, thalach | sex, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ sex | fbs, exang)
# (age _|_ restecg, chol, heartdisease, thalach | fbs, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, exang)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ restecg, thalach | heartdisease, chol)
# (age _|_ chol, thalach | sex, heartdisease, restecg)
# (age _|_ restecg, chol, heartdisease, thalach | sex, fbs, trestbps)
# (age _|_ restecg, chol, thalach | sex, fbs, heartdisease)
# (age _|_ restecg, chol, thalach | sex, heartdisease, exang)
# (age _|_ restecg, chol, thalach | sex, heartdisease, trestbps)
# (age _|_ restecg, chol | sex, heartdisease, thalach)
# (age _|_ restecg, thalach | sex, chol, heartdisease)
# (age _|_ heartdisease, chol, thalach | restecg, fbs, trestbps)
# (age _|_ chol, thalach | restecg, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease, exang)
# (age _|_ chol, thalach | restecg, heartdisease, trestbps)
# (age _|_ chol | restecg, heartdisease, thalach)
# (age _|_ thalach | restecg, chol, heartdisease)
# (age _|_ restecg, chol, heartdisease, thalach | fbs, exang, trestbps)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (age _|_ restecg, chol, heartdisease | fbs, trestbps, thalach)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, trestbps)
# (age _|_ restecg, heartdisease, thalach | chol, fbs, trestbps)
# (age _|_ restecg, chol | heartdisease, fbs, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, exang, trestbps)
# (age _|_ restecg, chol | heartdisease, exang, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, exang)
# (age _|_ restecg, chol | heartdisease, trestbps, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, trestbps)
# (age _|_ restecg | heartdisease, chol, thalach)
# (age _|_ heartdisease, chol, thalach | sex, fbs, restecg, trestbps)
# (age _|_ chol, thalach | sex, fbs, heartdisease, restecg)
# (age _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (age _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (age _|_ chol | sex, heartdisease, restecg, thalach)
# (age _|_ thalach | sex, chol, heartdisease, restecg)
# (age _|_ restecg, chol, heartdisease, thalach | sex, fbs, exang, trestbps)
# (age _|_ restecg, chol, thalach | sex, fbs, heartdisease, exang)
# (age _|_ restecg, chol, heartdisease | sex, fbs, trestbps, thalach)
# (age _|_ restecg, chol, thalach | sex, fbs, heartdisease, trestbps)
# (age _|_ restecg, heartdisease, thalach | sex, chol, fbs, trestbps)
# (age _|_ restecg, chol | sex, fbs, heartdisease, thalach)
# (age _|_ restecg, thalach | sex, chol, fbs, heartdisease)
# (age _|_ restecg, chol, thalach | sex, heartdisease, exang, trestbps)
# (age _|_ restecg, chol | sex, heartdisease, exang, thalach)
# (age _|_ restecg, thalach | sex, chol, heartdisease, exang)
# (age _|_ restecg, chol | sex, heartdisease, trestbps, thalach)
# (age _|_ restecg, thalach | sex, chol, heartdisease, trestbps)
# (age _|_ restecg | sex, chol, heartdisease, thalach)
# (age _|_ heartdisease, chol, thalach | restecg, fbs, exang, trestbps)
# (age _|_ chol, thalach | restecg, fbs, heartdisease, exang)
# (age _|_ heartdisease, chol | restecg, fbs, trestbps, thalach)
# (age _|_ chol, thalach | restecg, fbs, heartdisease, trestbps)
# (age _|_ heartdisease, thalach | restecg, chol, fbs, trestbps)
# (age _|_ chol | restecg, fbs, heartdisease, thalach)
# (age _|_ thalach | restecg, chol, fbs, heartdisease)
# (age _|_ chol, thalach | restecg, heartdisease, exang, trestbps)
# (age _|_ chol | restecg, heartdisease, exang, thalach)
# (age _|_ thalach | restecg, chol, heartdisease, exang)
# (age _|_ chol | restecg, heartdisease, trestbps, thalach)
# (age _|_ thalach | restecg, chol, heartdisease, trestbps)
# (age _|_ heartdisease, chol, restecg | fbs, exang, trestbps, thalach)
# (age _|_ restecg, chol, thalach | heartdisease, fbs, exang, trestbps)
# (age _|_ heartdisease, restecg, thalach | chol, fbs, exang, trestbps)
# (age _|_ restecg, chol | heartdisease, fbs, exang, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, fbs, exang)
# (age _|_ restecg, chol | heartdisease, fbs, trestbps, thalach)
# (age _|_ heartdisease, restecg | chol, fbs, trestbps, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, fbs, trestbps)
# (age _|_ restecg | heartdisease, chol, fbs, thalach)
# (age _|_ restecg, chol | heartdisease, exang, trestbps, thalach)
# (age _|_ restecg, thalach | heartdisease, chol, exang, trestbps)
# (age _|_ restecg | heartdisease, chol, exang, thalach)
# (age _|_ restecg | heartdisease, chol, trestbps, thalach)
# (age _|_ heartdisease, chol, thalach | sex, restecg, fbs, exang, trestbps)
# (age _|_ chol, thalach | sex, restecg, fbs, exang, heartdisease)
# (age _|_ heartdisease, chol | sex, restecg, fbs, trestbps, thalach)
# (age _|_ chol, thalach | sex, restecg, fbs, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | sex, restecg, fbs, trestbps, chol)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (age _|_ thalach | sex, restecg, fbs, heartdisease, chol)
# (age _|_ chol, thalach | sex, restecg, exang, trestbps, heartdisease)
# (age _|_ chol | sex, restecg, exang, thalach, heartdisease)
# (age _|_ thalach | sex, restecg, exang, heartdisease, chol)
# (age _|_ chol | sex, restecg, trestbps, thalach, heartdisease)
# (age _|_ thalach | sex, restecg, trestbps, heartdisease, chol)
# (age _|_ restecg, chol, heartdisease | sex, fbs, exang, trestbps, thalach)
# (age _|_ restecg, chol, thalach | sex, fbs, exang, trestbps, heartdisease)
# (age _|_ restecg, heartdisease, thalach | sex, fbs, exang, trestbps, chol)
# (age _|_ restecg, chol | sex, fbs, exang, thalach, heartdisease)
# (age _|_ restecg, thalach | sex, fbs, exang, heartdisease, chol)
# (age _|_ restecg, chol | sex, fbs, trestbps, thalach, heartdisease)
# (age _|_ restecg, heartdisease | sex, fbs, trestbps, thalach, chol)
# (age _|_ restecg, thalach | sex, fbs, trestbps, heartdisease, chol)
# (age _|_ restecg | sex, fbs, thalach, heartdisease, chol)
# (age _|_ restecg, chol | sex, exang, trestbps, thalach, heartdisease)
# (age _|_ restecg, thalach | sex, exang, trestbps, heartdisease, chol)
# (age _|_ restecg | sex, exang, thalach, heartdisease, chol)
# (age _|_ restecg | sex, trestbps, thalach, heartdisease, chol)
# (age _|_ heartdisease, chol | restecg, fbs, exang, trestbps, thalach)
# (age _|_ chol, thalach | restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | restecg, fbs, exang, trestbps, chol)
# (age _|_ chol | restecg, fbs, exang, thalach, heartdisease)
# (age _|_ thalach | restecg, fbs, exang, heartdisease, chol)
# (age _|_ chol | restecg, fbs, trestbps, thalach, heartdisease)
# (age _|_ heartdisease | restecg, fbs, trestbps, thalach, chol)
# (age _|_ thalach | restecg, fbs, trestbps, heartdisease, chol)
# (age _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (age _|_ thalach | restecg, exang, trestbps, heartdisease, chol)
# (age _|_ restecg, chol | fbs, exang, trestbps, thalach, heartdisease)
# (age _|_ heartdisease, restecg | fbs, exang, trestbps, thalach, chol)
# (age _|_ restecg, thalach | fbs, exang, trestbps, heartdisease, chol)
# (age _|_ restecg | fbs, exang, thalach, heartdisease, chol)
# (age _|_ restecg | fbs, trestbps, thalach, heartdisease, chol)
# (age _|_ restecg | exang, trestbps, thalach, heartdisease, chol)
# (age _|_ heartdisease, chol | sex, restecg, fbs, exang, trestbps, thalach)
# (age _|_ chol, thalach | sex, restecg, fbs, exang, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | sex, restecg, fbs, exang, trestbps, chol)
# (age _|_ chol | sex, restecg, fbs, exang, thalach, heartdisease)
# (age _|_ thalach | sex, restecg, fbs, exang, heartdisease, chol)
# (age _|_ chol | sex, restecg, fbs, trestbps, thalach, heartdisease)
# (age _|_ heartdisease | sex, restecg, fbs, trestbps, thalach, chol)
# (age _|_ thalach | sex, restecg, fbs, trestbps, heartdisease, chol)
# (age _|_ chol | sex, restecg, exang, trestbps, thalach, heartdisease)
# (age _|_ thalach | sex, restecg, exang, trestbps, heartdisease, chol)
# (age _|_ restecg, chol | sex, fbs, exang, trestbps, thalach, heartdisease)
# (age _|_ restecg, heartdisease | sex, fbs, exang, trestbps, thalach, chol)
# (age _|_ restecg, thalach | sex, fbs, exang, trestbps, heartdisease, chol)
# (age _|_ restecg | sex, fbs, exang, thalach, heartdisease, chol)
# (age _|_ restecg | sex, fbs, trestbps, thalach, heartdisease, chol)
# (age _|_ restecg | sex, exang, trestbps, thalach, heartdisease, chol)
# (age _|_ chol | restecg, fbs, exang, trestbps, thalach, heartdisease)
# (age _|_ heartdisease | restecg, fbs, exang, trestbps, thalach, chol)
# (age _|_ thalach | restecg, fbs, exang, trestbps, heartdisease, chol)
# (age _|_ restecg | fbs, exang, trestbps, thalach, heartdisease, chol)
# (age _|_ chol | sex, restecg, fbs, exang, trestbps, thalach, heartdisease)
# (age _|_ heartdisease | sex, restecg, fbs, exang, trestbps, thalach, chol)
# (age _|_ thalach | sex, restecg, fbs, exang, trestbps, heartdisease, chol)
# (age _|_ restecg | sex, fbs, exang, trestbps, thalach, heartdisease, chol)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg)
# (trestbps _|_ restecg, chol, thalach | sex, fbs, heartdisease)
# (trestbps _|_ fbs | sex, age, exang)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | sex, age, heartdisease)
# (trestbps _|_ restecg, chol | sex, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | sex, chol, heartdisease)
# (trestbps _|_ chol, thalach | restecg, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, heartdisease, exang)
# (trestbps _|_ chol, thalach | restecg, age, heartdisease)
# (trestbps _|_ chol | restecg, heartdisease, thalach)
# (trestbps _|_ thalach | restecg, chol, heartdisease)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs, age)
# (trestbps _|_ restecg, chol | heartdisease, fbs, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, age, exang)
# (trestbps _|_ restecg, chol | heartdisease, exang, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, exang)
# (trestbps _|_ restecg, chol | heartdisease, age, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age)
# (trestbps _|_ restecg | heartdisease, chol, thalach)
# (trestbps _|_ chol, thalach | sex, fbs, heartdisease, restecg)
# (trestbps _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (trestbps _|_ chol, thalach | sex, age, heartdisease, restecg)
# (trestbps _|_ chol | sex, heartdisease, restecg, thalach)
# (trestbps _|_ thalach | sex, chol, heartdisease, restecg)
# (trestbps _|_ restecg, chol, thalach | sex, fbs, heartdisease, exang)
# (trestbps _|_ restecg, chol, thalach | sex, fbs, heartdisease, age)
# (trestbps _|_ restecg, chol | sex, fbs, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | sex, chol, fbs, heartdisease)
# (trestbps _|_ restecg, chol, thalach | sex, age, heartdisease, exang)
# (trestbps _|_ restecg, chol | sex, heartdisease, exang, thalach)
# (trestbps _|_ restecg, thalach | sex, chol, heartdisease, exang)
# (trestbps _|_ restecg, chol | sex, age, heartdisease, thalach)
# (trestbps _|_ restecg, thalach | sex, chol, age, heartdisease)
# (trestbps _|_ restecg | sex, chol, heartdisease, thalach)
# (trestbps _|_ chol, thalach | restecg, fbs, heartdisease, exang)
# (trestbps _|_ chol, thalach | restecg, fbs, heartdisease, age)
# (trestbps _|_ chol | restecg, fbs, heartdisease, thalach)
# (trestbps _|_ thalach | restecg, chol, fbs, heartdisease)
# (trestbps _|_ chol, thalach | restecg, age, heartdisease, exang)
# (trestbps _|_ chol | restecg, heartdisease, exang, thalach)
# (trestbps _|_ thalach | restecg, chol, heartdisease, exang)
# (trestbps _|_ chol | restecg, age, heartdisease, thalach)
# (trestbps _|_ thalach | restecg, chol, age, heartdisease)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs, age, exang)
# (trestbps _|_ restecg, chol | heartdisease, fbs, exang, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs, exang)
# (trestbps _|_ restecg, chol | heartdisease, fbs, age, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs, age)
# (trestbps _|_ restecg | heartdisease, chol, fbs, thalach)
# (trestbps _|_ restecg, chol | heartdisease, age, exang, thalach)
# (trestbps _|_ restecg, thalach | heartdisease, chol, age, exang)
# (trestbps _|_ restecg | heartdisease, chol, exang, thalach)
# (trestbps _|_ restecg | heartdisease, chol, age, thalach)
# (trestbps _|_ chol, thalach | sex, restecg, fbs, exang, heartdisease)
# (trestbps _|_ chol, thalach | sex, restecg, fbs, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, fbs, heartdisease, chol)
# (trestbps _|_ chol, thalach | sex, restecg, exang, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, exang, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, exang, heartdisease, chol)
# (trestbps _|_ chol | sex, restecg, age, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, age, heartdisease, chol)
# (trestbps _|_ restecg, chol, thalach | sex, fbs, exang, age, heartdisease)
# (trestbps _|_ restecg, chol | sex, fbs, exang, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, fbs, exang, heartdisease, chol)
# (trestbps _|_ restecg, chol | sex, fbs, age, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, fbs, age, heartdisease, chol)
# (trestbps _|_ restecg | sex, fbs, thalach, heartdisease, chol)
# (trestbps _|_ restecg, chol | sex, exang, age, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, exang, age, heartdisease, chol)
# (trestbps _|_ restecg | sex, exang, thalach, heartdisease, chol)
# (trestbps _|_ restecg | sex, age, thalach, heartdisease, chol)
# (trestbps _|_ chol, thalach | restecg, fbs, exang, age, heartdisease)
# (trestbps _|_ chol | restecg, fbs, exang, thalach, heartdisease)
# (trestbps _|_ thalach | restecg, fbs, exang, heartdisease, chol)
# (trestbps _|_ chol | restecg, fbs, age, thalach, heartdisease)
# (trestbps _|_ thalach | restecg, fbs, age, heartdisease, chol)
# (trestbps _|_ chol | restecg, exang, age, thalach, heartdisease)
# (trestbps _|_ thalach | restecg, exang, age, heartdisease, chol)
# (trestbps _|_ restecg, chol | fbs, exang, age, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, exang, age, heartdisease, chol)
# (trestbps _|_ restecg | fbs, exang, thalach, heartdisease, chol)
# (trestbps _|_ restecg | fbs, age, thalach, heartdisease, chol)
# (trestbps _|_ restecg | exang, age, thalach, heartdisease, chol)
# (trestbps _|_ chol, thalach | sex, restecg, fbs, exang, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, fbs, exang, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, fbs, exang, heartdisease, chol)
# (trestbps _|_ chol | sex, restecg, fbs, age, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, fbs, age, heartdisease, chol)
# (trestbps _|_ chol | sex, restecg, exang, age, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, exang, age, heartdisease, chol)
# (trestbps _|_ restecg, chol | sex, fbs, exang, age, thalach, heartdisease)
# (trestbps _|_ restecg, thalach | sex, fbs, exang, age, heartdisease, chol)
# (trestbps _|_ restecg | sex, fbs, exang, thalach, heartdisease, chol)
# (trestbps _|_ restecg | sex, fbs, age, thalach, heartdisease, chol)
# (trestbps _|_ restecg | sex, exang, age, thalach, heartdisease, chol)
# (trestbps _|_ chol | restecg, fbs, exang, age, thalach, heartdisease)
# (trestbps _|_ thalach | restecg, fbs, exang, age, heartdisease, chol)
# (trestbps _|_ restecg | fbs, exang, age, thalach, heartdisease, chol)
# (trestbps _|_ chol | sex, restecg, fbs, exang, age, thalach, heartdisease)
# (trestbps _|_ thalach | sex, restecg, fbs, exang, age, heartdisease, chol)
# (trestbps _|_ restecg | sex, fbs, exang, age, thalach, heartdisease, chol)
# (fbs _|_ sex, exang)
# (fbs _|_ exang | sex)
# (fbs _|_ sex | exang)
# (fbs _|_ sex, exang, trestbps | age)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ exang, trestbps | sex, age)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, age)
# (fbs _|_ restecg, chol, thalach | heartdisease, trestbps)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg)
# (fbs _|_ trestbps | sex, age, exang)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease, exang)
# (fbs _|_ exang | sex, age, trestbps)
# (fbs _|_ restecg, chol, thalach | sex, age, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease, trestbps)
# (fbs _|_ restecg, chol | sex, heartdisease, thalach)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease, exang)
# (fbs _|_ sex, exang | restecg, age, trestbps)
# (fbs _|_ chol, thalach | restecg, age, heartdisease)
# (fbs _|_ chol, thalach | restecg, heartdisease, trestbps)
# (fbs _|_ chol | restecg, heartdisease, thalach)
# (fbs _|_ thalach | restecg, chol, heartdisease)
# (fbs _|_ sex | age, exang, trestbps)
# (fbs _|_ restecg, chol, thalach | heartdisease, age, exang)
# (fbs _|_ restecg, chol, thalach | heartdisease, exang, trestbps)
# (fbs _|_ restecg, chol | heartdisease, exang, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, exang)
# (fbs _|_ sex, exang | age, trestbps, thalach)
# (fbs _|_ sex, restecg, thalach, chol, exang | heartdisease, age, trestbps)
# (fbs _|_ sex, exang | chol, age, trestbps)
# (fbs _|_ restecg, chol | heartdisease, age, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, age)
# (fbs _|_ restecg, chol | heartdisease, trestbps, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, trestbps)
# (fbs _|_ restecg | heartdisease, chol, thalach)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, exang)
# (fbs _|_ exang | sex, age, restecg, trestbps)
# (fbs _|_ chol, thalach | sex, age, heartdisease, restecg)
# (fbs _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (fbs _|_ chol | sex, heartdisease, restecg, thalach)
# (fbs _|_ thalach | sex, chol, heartdisease, restecg)
# (fbs _|_ restecg, chol, thalach | sex, age, heartdisease, exang)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease, exang, trestbps)
# (fbs _|_ restecg, chol | sex, heartdisease, exang, thalach)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease, exang)
# (fbs _|_ exang | sex, age, trestbps, thalach)
# (fbs _|_ restecg, chol, exang, thalach | sex, age, heartdisease, trestbps)
# (fbs _|_ exang | sex, chol, age, trestbps)
# (fbs _|_ restecg, chol | sex, age, heartdisease, thalach)
# (fbs _|_ restecg, thalach | sex, chol, age, heartdisease)
# (fbs _|_ restecg, chol | sex, heartdisease, trestbps, thalach)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease, trestbps)
# (fbs _|_ restecg | sex, chol, heartdisease, thalach)
# (fbs _|_ sex | restecg, age, exang, trestbps)
# (fbs _|_ chol, thalach | restecg, age, heartdisease, exang)
# (fbs _|_ chol, thalach | restecg, heartdisease, exang, trestbps)
# (fbs _|_ chol | restecg, heartdisease, exang, thalach)
# (fbs _|_ thalach | restecg, chol, heartdisease, exang)
# (fbs _|_ sex, exang | restecg, age, trestbps, thalach)
# (fbs _|_ sex, chol, exang, thalach | restecg, age, heartdisease, trestbps)
# (fbs _|_ sex, exang | restecg, chol, age, trestbps)
# (fbs _|_ chol | restecg, age, heartdisease, thalach)
# (fbs _|_ thalach | restecg, chol, age, heartdisease)
# (fbs _|_ chol | restecg, heartdisease, trestbps, thalach)
# (fbs _|_ thalach | restecg, chol, heartdisease, trestbps)
# (fbs _|_ sex | age, exang, trestbps, thalach)
# (fbs _|_ sex, chol, restecg, thalach | heartdisease, age, exang, trestbps)
# (fbs _|_ sex | chol, age, exang, trestbps)
# (fbs _|_ restecg, chol | heartdisease, age, exang, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, age, exang)
# (fbs _|_ restecg, chol | heartdisease, exang, trestbps, thalach)
# (fbs _|_ restecg, thalach | heartdisease, chol, exang, trestbps)
# (fbs _|_ restecg | heartdisease, chol, exang, thalach)
# (fbs _|_ sex, chol, restecg, exang | heartdisease, age, trestbps, thalach)
# (fbs _|_ sex, exang | chol, age, trestbps, thalach)
# (fbs _|_ sex, restecg, exang, thalach | heartdisease, chol, age, trestbps)
# (fbs _|_ restecg | heartdisease, chol, age, thalach)
# (fbs _|_ restecg | heartdisease, chol, trestbps, thalach)
# (fbs _|_ chol, thalach | sex, restecg, exang, age, heartdisease)
# (fbs _|_ chol, thalach | sex, restecg, exang, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, exang, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, exang, heartdisease, chol)
# (fbs _|_ exang | sex, restecg, age, trestbps, thalach)
# (fbs _|_ chol, exang, thalach | sex, restecg, age, trestbps, heartdisease)
# (fbs _|_ exang | sex, restecg, age, trestbps, chol)
# (fbs _|_ chol | sex, restecg, age, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, age, heartdisease, chol)
# (fbs _|_ chol | sex, restecg, trestbps, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, trestbps, heartdisease, chol)
# (fbs _|_ restecg, chol, thalach | sex, exang, age, trestbps, heartdisease)
# (fbs _|_ restecg, chol | sex, exang, age, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, age, heartdisease, chol)
# (fbs _|_ restecg, chol | sex, exang, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, trestbps, heartdisease, chol)
# (fbs _|_ restecg | sex, exang, thalach, heartdisease, chol)
# (fbs _|_ restecg, chol, exang | sex, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang | sex, age, trestbps, thalach, chol)
# (fbs _|_ restecg, exang, thalach | sex, age, trestbps, heartdisease, chol)
# (fbs _|_ restecg | sex, age, thalach, heartdisease, chol)
# (fbs _|_ restecg | sex, trestbps, thalach, heartdisease, chol)
# (fbs _|_ sex | restecg, exang, age, trestbps, thalach)
# (fbs _|_ sex, chol, thalach | restecg, exang, age, trestbps, heartdisease)
# (fbs _|_ sex | restecg, exang, age, trestbps, chol)
# (fbs _|_ chol | restecg, exang, age, thalach, heartdisease)
# (fbs _|_ thalach | restecg, exang, age, heartdisease, chol)
# (fbs _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (fbs _|_ thalach | restecg, exang, trestbps, heartdisease, chol)
# (fbs _|_ sex, chol, exang | restecg, age, trestbps, thalach, heartdisease)
# (fbs _|_ sex, exang | restecg, age, trestbps, thalach, chol)
# (fbs _|_ sex, exang, thalach | restecg, age, trestbps, heartdisease, chol)
# (fbs _|_ sex, chol, restecg | exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ sex | exang, age, trestbps, thalach, chol)
# (fbs _|_ sex, restecg, thalach | exang, age, trestbps, heartdisease, chol)
# (fbs _|_ restecg | exang, age, thalach, heartdisease, chol)
# (fbs _|_ restecg | exang, trestbps, thalach, heartdisease, chol)
# (fbs _|_ sex, restecg, exang | age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ chol, thalach | sex, restecg, exang, age, trestbps, heartdisease)
# (fbs _|_ chol | sex, restecg, exang, age, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, exang, age, heartdisease, chol)
# (fbs _|_ chol | sex, restecg, exang, trestbps, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, exang, trestbps, heartdisease, chol)
# (fbs _|_ chol, exang | sex, restecg, age, trestbps, thalach, heartdisease)
# (fbs _|_ exang | sex, restecg, age, trestbps, thalach, chol)
# (fbs _|_ exang, thalach | sex, restecg, age, trestbps, heartdisease, chol)
# (fbs _|_ restecg, chol | sex, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ restecg, thalach | sex, exang, age, trestbps, heartdisease, chol)
# (fbs _|_ restecg | sex, exang, age, thalach, heartdisease, chol)
# (fbs _|_ restecg | sex, exang, trestbps, thalach, heartdisease, chol)
# (fbs _|_ restecg, exang | sex, age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ sex, chol | restecg, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ sex | restecg, exang, age, trestbps, thalach, chol)
# (fbs _|_ sex, thalach | restecg, exang, age, trestbps, heartdisease, chol)
# (fbs _|_ sex, exang | restecg, age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ sex, restecg | exang, age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ chol | sex, restecg, exang, age, trestbps, thalach, heartdisease)
# (fbs _|_ thalach | sex, restecg, exang, age, trestbps, heartdisease, chol)
# (fbs _|_ exang | sex, restecg, age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ restecg | sex, exang, age, trestbps, thalach, heartdisease, chol)
# (fbs _|_ sex | restecg, exang, age, trestbps, thalach, heartdisease, chol)
# (sex _|_ fbs, age, exang)
# (sex _|_ age, exang | fbs)
# (sex _|_ fbs, age | exang)
# (sex _|_ fbs, exang | age)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ age | fbs, exang)
# (sex _|_ exang | fbs, age)
# (sex _|_ restecg, chol, heartdisease, thalach | fbs, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs)
# (sex _|_ fbs | age, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, exang)
# (sex _|_ restecg, thalach, heartdisease, chol, fbs | age, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, age)
# (sex _|_ restecg, chol, thalach | heartdisease, trestbps)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol)
# (sex _|_ heartdisease, chol, thalach | restecg, fbs, trestbps)
# (sex _|_ chol, thalach | restecg, fbs, heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease, exang)
# (sex _|_ heartdisease, chol, fbs, thalach | restecg, age, trestbps)
# (sex _|_ chol, thalach | restecg, age, heartdisease)
# (sex _|_ chol, thalach | restecg, heartdisease, trestbps)
# (sex _|_ chol | restecg, heartdisease, thalach)
# (sex _|_ thalach | restecg, chol, heartdisease)
# (sex _|_ restecg, chol, heartdisease, thalach | fbs, exang, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, exang)
# (sex _|_ restecg, chol, heartdisease, thalach | fbs, age, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, age)
# (sex _|_ restecg, chol, heartdisease | fbs, trestbps, thalach)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, trestbps)
# (sex _|_ restecg, heartdisease, thalach | chol, fbs, trestbps)
# (sex _|_ restecg, chol | heartdisease, fbs, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs)
# (sex _|_ restecg, thalach, heartdisease, chol, fbs | age, exang, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, age, exang)
# (sex _|_ restecg, chol, thalach | heartdisease, exang, trestbps)
# (sex _|_ restecg, chol | heartdisease, exang, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, exang)
# (sex _|_ restecg, chol, fbs, heartdisease | age, trestbps, thalach)
# (sex _|_ restecg, chol, fbs, thalach | heartdisease, age, trestbps)
# (sex _|_ restecg, fbs, heartdisease, thalach | chol, age, trestbps)
# (sex _|_ restecg, chol | heartdisease, age, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, age)
# (sex _|_ restecg, chol | heartdisease, trestbps, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, trestbps)
# (sex _|_ restecg | heartdisease, chol, thalach)
# (sex _|_ heartdisease, chol, thalach | restecg, fbs, exang, trestbps)
# (sex _|_ chol, thalach | restecg, fbs, heartdisease, exang)
# (sex _|_ heartdisease, chol, thalach | restecg, fbs, age, trestbps)
# (sex _|_ chol, thalach | restecg, fbs, heartdisease, age)
# (sex _|_ heartdisease, chol | restecg, fbs, trestbps, thalach)
# (sex _|_ chol, thalach | restecg, fbs, heartdisease, trestbps)
# (sex _|_ heartdisease, thalach | restecg, chol, fbs, trestbps)
# (sex _|_ chol | restecg, fbs, heartdisease, thalach)
# (sex _|_ thalach | restecg, chol, fbs, heartdisease)
# (sex _|_ heartdisease, chol, fbs, thalach | restecg, age, exang, trestbps)
# (sex _|_ chol, thalach | restecg, age, heartdisease, exang)
# (sex _|_ chol, thalach | restecg, heartdisease, exang, trestbps)
# (sex _|_ chol | restecg, heartdisease, exang, thalach)
# (sex _|_ thalach | restecg, chol, heartdisease, exang)
# (sex _|_ heartdisease, chol, fbs | restecg, age, trestbps, thalach)
# (sex _|_ chol, fbs, thalach | restecg, age, heartdisease, trestbps)
# (sex _|_ heartdisease, fbs, thalach | restecg, chol, age, trestbps)
# (sex _|_ chol | restecg, age, heartdisease, thalach)
# (sex _|_ thalach | restecg, chol, age, heartdisease)
# (sex _|_ chol | restecg, heartdisease, trestbps, thalach)
# (sex _|_ thalach | restecg, chol, heartdisease, trestbps)
# (sex _|_ restecg, chol, heartdisease, thalach | fbs, age, exang, trestbps)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, age, exang)
# (sex _|_ restecg, chol, heartdisease | fbs, exang, trestbps, thalach)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, exang, trestbps)
# (sex _|_ restecg, heartdisease, thalach | chol, fbs, exang, trestbps)
# (sex _|_ restecg, chol | heartdisease, fbs, exang, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs, exang)
# (sex _|_ restecg, chol, heartdisease | fbs, age, trestbps, thalach)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs, age, trestbps)
# (sex _|_ restecg, heartdisease, thalach | chol, fbs, age, trestbps)
# (sex _|_ restecg, chol | heartdisease, fbs, age, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs, age)
# (sex _|_ restecg, chol | heartdisease, fbs, trestbps, thalach)
# (sex _|_ restecg, heartdisease | chol, fbs, trestbps, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, fbs, trestbps)
# (sex _|_ restecg | heartdisease, chol, fbs, thalach)
# (sex _|_ restecg, chol, fbs, heartdisease | age, exang, trestbps, thalach)
# (sex _|_ restecg, chol, fbs, thalach | heartdisease, age, exang, trestbps)
# (sex _|_ restecg, fbs, heartdisease, thalach | chol, age, exang, trestbps)
# (sex _|_ restecg, chol | heartdisease, age, exang, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, age, exang)
# (sex _|_ restecg, chol | heartdisease, exang, trestbps, thalach)
# (sex _|_ restecg, thalach | heartdisease, chol, exang, trestbps)
# (sex _|_ restecg | heartdisease, chol, exang, thalach)
# (sex _|_ restecg, chol, fbs | heartdisease, age, trestbps, thalach)
# (sex _|_ restecg, fbs, heartdisease | chol, age, trestbps, thalach)
# (sex _|_ restecg, fbs, thalach | heartdisease, chol, age, trestbps)
# (sex _|_ restecg | heartdisease, chol, age, thalach)
# (sex _|_ restecg | heartdisease, chol, trestbps, thalach)
# (sex _|_ heartdisease, chol, thalach | restecg, fbs, exang, age, trestbps)
# (sex _|_ chol, thalach | restecg, fbs, exang, age, heartdisease)
# (sex _|_ heartdisease, chol | restecg, fbs, exang, trestbps, thalach)
# (sex _|_ chol, thalach | restecg, fbs, exang, trestbps, heartdisease)
# (sex _|_ heartdisease, thalach | restecg, fbs, exang, trestbps, chol)
# (sex _|_ chol | restecg, fbs, exang, thalach, heartdisease)
# (sex _|_ thalach | restecg, fbs, exang, heartdisease, chol)
# (sex _|_ heartdisease, chol | restecg, fbs, age, trestbps, thalach)
# (sex _|_ chol, thalach | restecg, fbs, age, trestbps, heartdisease)
# (sex _|_ heartdisease, thalach | restecg, fbs, age, trestbps, chol)
# (sex _|_ chol | restecg, fbs, age, thalach, heartdisease)
# (sex _|_ thalach | restecg, fbs, age, heartdisease, chol)
# (sex _|_ chol | restecg, fbs, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, fbs, trestbps, thalach, chol)
# (sex _|_ thalach | restecg, fbs, trestbps, heartdisease, chol)
# (sex _|_ heartdisease, chol, fbs | restecg, exang, age, trestbps, thalach)
# (sex _|_ chol, fbs, thalach | restecg, exang, age, trestbps, heartdisease)
# (sex _|_ heartdisease, fbs, thalach | restecg, exang, age, trestbps, chol)
# (sex _|_ chol | restecg, exang, age, thalach, heartdisease)
# (sex _|_ thalach | restecg, exang, age, heartdisease, chol)
# (sex _|_ chol | restecg, exang, trestbps, thalach, heartdisease)
# (sex _|_ thalach | restecg, exang, trestbps, heartdisease, chol)
# (sex _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease, fbs | restecg, age, trestbps, thalach, chol)
# (sex _|_ fbs, thalach | restecg, age, trestbps, heartdisease, chol)
# (sex _|_ restecg, chol, heartdisease | fbs, exang, age, trestbps, thalach)
# (sex _|_ restecg, chol, thalach | fbs, exang, age, trestbps, heartdisease)
# (sex _|_ restecg, heartdisease, thalach | fbs, exang, age, trestbps, chol)
# (sex _|_ restecg, chol | fbs, exang, age, thalach, heartdisease)
# (sex _|_ restecg, thalach | fbs, exang, age, heartdisease, chol)
# (sex _|_ restecg, chol | fbs, exang, trestbps, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | fbs, exang, trestbps, thalach, chol)
# (sex _|_ restecg, thalach | fbs, exang, trestbps, heartdisease, chol)
# (sex _|_ restecg | fbs, exang, thalach, heartdisease, chol)
# (sex _|_ restecg, chol | fbs, age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | fbs, age, trestbps, thalach, chol)
# (sex _|_ restecg, thalach | fbs, age, trestbps, heartdisease, chol)
# (sex _|_ restecg | fbs, age, thalach, heartdisease, chol)
# (sex _|_ restecg | fbs, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg, chol, fbs | exang, age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, fbs, heartdisease | exang, age, trestbps, thalach, chol)
# (sex _|_ restecg, fbs, thalach | exang, age, trestbps, heartdisease, chol)
# (sex _|_ restecg | exang, age, thalach, heartdisease, chol)
# (sex _|_ restecg | exang, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg, fbs | age, trestbps, thalach, heartdisease, chol)
# (sex _|_ heartdisease, chol | restecg, fbs, exang, age, trestbps, thalach)
# (sex _|_ chol, thalach | restecg, fbs, exang, age, trestbps, heartdisease)
# (sex _|_ heartdisease, thalach | restecg, fbs, exang, age, trestbps, chol)
# (sex _|_ chol | restecg, fbs, exang, age, thalach, heartdisease)
# (sex _|_ thalach | restecg, fbs, exang, age, heartdisease, chol)
# (sex _|_ chol | restecg, fbs, exang, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, fbs, exang, trestbps, thalach, chol)
# (sex _|_ thalach | restecg, fbs, exang, trestbps, heartdisease, chol)
# (sex _|_ chol | restecg, fbs, age, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, fbs, age, trestbps, thalach, chol)
# (sex _|_ thalach | restecg, fbs, age, trestbps, heartdisease, chol)
# (sex _|_ chol, fbs | restecg, exang, age, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease, fbs | restecg, exang, age, trestbps, thalach, chol)
# (sex _|_ fbs, thalach | restecg, exang, age, trestbps, heartdisease, chol)
# (sex _|_ fbs | restecg, age, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg, chol | fbs, exang, age, trestbps, thalach, heartdisease)
# (sex _|_ restecg, heartdisease | fbs, exang, age, trestbps, thalach, chol)
# (sex _|_ restecg, thalach | fbs, exang, age, trestbps, heartdisease, chol)
# (sex _|_ restecg | fbs, exang, age, thalach, heartdisease, chol)
# (sex _|_ restecg | fbs, exang, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg | fbs, age, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg, fbs | exang, age, trestbps, thalach, heartdisease, chol)
# (sex _|_ chol | restecg, fbs, exang, age, trestbps, thalach, heartdisease)
# (sex _|_ heartdisease | restecg, fbs, exang, age, trestbps, thalach, chol)
# (sex _|_ thalach | restecg, fbs, exang, age, trestbps, heartdisease, chol)
# (sex _|_ fbs | restecg, exang, age, trestbps, thalach, heartdisease, chol)
# (sex _|_ restecg | fbs, exang, age, trestbps, thalach, heartdisease, chol)
# (exang _|_ sex, fbs, age)
# (exang _|_ fbs, age | sex)
# (exang _|_ sex, age | fbs)
# (exang _|_ sex, fbs | age)
# (exang _|_ restecg, chol, thalach | heartdisease)
# (exang _|_ age | sex, fbs)
# (exang _|_ fbs | sex, age)
# (exang _|_ restecg, chol, thalach | sex, heartdisease)
# (exang _|_ chol, thalach | restecg, heartdisease)
# (exang _|_ sex | fbs, age)
# (exang _|_ restecg, chol, heartdisease, thalach | fbs, trestbps)
# (exang _|_ restecg, chol, thalach | heartdisease, fbs)
# (exang _|_ restecg, thalach, heartdisease, chol, fbs | age, trestbps)
# (exang _|_ restecg, chol, thalach | heartdisease, age)
# (exang _|_ restecg, chol, thalach | heartdisease, trestbps)
# (exang _|_ restecg, chol | heartdisease, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol)
# (exang _|_ chol, thalach | sex, heartdisease, restecg)
# (exang _|_ restecg, chol, heartdisease, thalach | sex, fbs, trestbps)
# (exang _|_ restecg, chol, thalach | sex, fbs, heartdisease)
# (exang _|_ restecg, thalach, heartdisease, chol, fbs | sex, age, trestbps)
# (exang _|_ restecg, chol, thalach | sex, age, heartdisease)
# (exang _|_ restecg, chol, thalach | sex, heartdisease, trestbps)
# (exang _|_ restecg, chol | sex, heartdisease, thalach)
# (exang _|_ restecg, thalach | sex, chol, heartdisease)
# (exang _|_ heartdisease, chol, thalach | restecg, fbs, trestbps)
# (exang _|_ chol, thalach | restecg, fbs, heartdisease)
# (exang _|_ heartdisease, chol, fbs, thalach | restecg, age, trestbps)
# (exang _|_ chol, thalach | restecg, age, heartdisease)
# (exang _|_ chol, thalach | restecg, heartdisease, trestbps)
# (exang _|_ chol | restecg, heartdisease, thalach)
# (exang _|_ thalach | restecg, chol, heartdisease)
# (exang _|_ restecg, chol, heartdisease, thalach | fbs, age, trestbps)
# (exang _|_ restecg, chol, thalach | heartdisease, fbs, age)
# (exang _|_ restecg, chol, heartdisease | fbs, trestbps, thalach)
# (exang _|_ restecg, chol, thalach | heartdisease, fbs, trestbps)
# (exang _|_ restecg, heartdisease, thalach | chol, fbs, trestbps)
# (exang _|_ restecg, chol | heartdisease, fbs, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, fbs)
# (exang _|_ restecg, chol, fbs, heartdisease | age, trestbps, thalach)
# (exang _|_ restecg, chol, fbs, thalach | heartdisease, age, trestbps)
# (exang _|_ restecg, fbs, heartdisease, thalach | chol, age, trestbps)
# (exang _|_ restecg, chol | heartdisease, age, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, age)
# (exang _|_ restecg, chol | heartdisease, trestbps, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, trestbps)
# (exang _|_ restecg | heartdisease, chol, thalach)
# (exang _|_ heartdisease, chol, thalach | sex, fbs, restecg, trestbps)
# (exang _|_ chol, thalach | sex, fbs, heartdisease, restecg)
# (exang _|_ heartdisease, chol, fbs, thalach | sex, age, restecg, trestbps)
# (exang _|_ chol, thalach | sex, age, heartdisease, restecg)
# (exang _|_ chol, thalach | sex, heartdisease, restecg, trestbps)
# (exang _|_ chol | sex, heartdisease, restecg, thalach)
# (exang _|_ thalach | sex, chol, heartdisease, restecg)
# (exang _|_ restecg, chol, heartdisease, thalach | sex, fbs, age, trestbps)
# (exang _|_ restecg, chol, thalach | sex, fbs, heartdisease, age)
# (exang _|_ restecg, chol, heartdisease | sex, fbs, trestbps, thalach)
# (exang _|_ restecg, chol, thalach | sex, fbs, heartdisease, trestbps)
# (exang _|_ restecg, heartdisease, thalach | sex, chol, fbs, trestbps)
# (exang _|_ restecg, chol | sex, fbs, heartdisease, thalach)
# (exang _|_ restecg, thalach | sex, chol, fbs, heartdisease)
# (exang _|_ restecg, chol, fbs, heartdisease | sex, age, trestbps, thalach)
# (exang _|_ restecg, chol, fbs, thalach | sex, age, heartdisease, trestbps)
# (exang _|_ restecg, fbs, heartdisease, thalach | sex, chol, age, trestbps)
# (exang _|_ restecg, chol | sex, age, heartdisease, thalach)
# (exang _|_ restecg, thalach | sex, chol, age, heartdisease)
# (exang _|_ restecg, chol | sex, heartdisease, trestbps, thalach)
# (exang _|_ restecg, thalach | sex, chol, heartdisease, trestbps)
# (exang _|_ restecg | sex, chol, heartdisease, thalach)
# (exang _|_ heartdisease, chol, thalach | restecg, fbs, age, trestbps)
# (exang _|_ chol, thalach | restecg, fbs, heartdisease, age)
# (exang _|_ heartdisease, chol | restecg, fbs, trestbps, thalach)
# (exang _|_ chol, thalach | restecg, fbs, heartdisease, trestbps)
# (exang _|_ heartdisease, thalach | restecg, chol, fbs, trestbps)
# (exang _|_ chol | restecg, fbs, heartdisease, thalach)
# (exang _|_ thalach | restecg, chol, fbs, heartdisease)
# (exang _|_ heartdisease, chol, fbs | restecg, age, trestbps, thalach)
# (exang _|_ chol, fbs, thalach | restecg, age, heartdisease, trestbps)
# (exang _|_ heartdisease, fbs, thalach | restecg, chol, age, trestbps)
# (exang _|_ chol | restecg, age, heartdisease, thalach)
# (exang _|_ thalach | restecg, chol, age, heartdisease)
# (exang _|_ chol | restecg, heartdisease, trestbps, thalach)
# (exang _|_ thalach | restecg, chol, heartdisease, trestbps)
# (exang _|_ heartdisease, chol, restecg | fbs, age, trestbps, thalach)
# (exang _|_ restecg, chol, thalach | heartdisease, fbs, age, trestbps)
# (exang _|_ heartdisease, restecg, thalach | chol, fbs, age, trestbps)
# (exang _|_ restecg, chol | heartdisease, fbs, age, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, fbs, age)
# (exang _|_ restecg, chol | heartdisease, fbs, trestbps, thalach)
# (exang _|_ heartdisease, restecg | chol, fbs, trestbps, thalach)
# (exang _|_ restecg, thalach | heartdisease, chol, fbs, trestbps)
# (exang _|_ restecg | heartdisease, chol, fbs, thalach)
# (exang _|_ restecg, chol, fbs | heartdisease, age, trestbps, thalach)
# (exang _|_ heartdisease, fbs, restecg | chol, age, trestbps, thalach)
# (exang _|_ restecg, fbs, thalach | heartdisease, chol, age, trestbps)
# (exang _|_ restecg | heartdisease, chol, age, thalach)
# (exang _|_ restecg | heartdisease, chol, trestbps, thalach)
# (exang _|_ heartdisease, chol, thalach | sex, restecg, fbs, age, trestbps)
# (exang _|_ chol, thalach | sex, restecg, fbs, age, heartdisease)
# (exang _|_ heartdisease, chol | sex, restecg, fbs, trestbps, thalach)
# (exang _|_ chol, thalach | sex, restecg, fbs, trestbps, heartdisease)
# (exang _|_ heartdisease, thalach | sex, restecg, fbs, trestbps, chol)
# (exang _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (exang _|_ thalach | sex, restecg, fbs, heartdisease, chol)
# (exang _|_ heartdisease, chol, fbs | sex, restecg, age, trestbps, thalach)
# (exang _|_ chol, fbs, thalach | sex, restecg, age, trestbps, heartdisease)
# (exang _|_ heartdisease, fbs, thalach | sex, restecg, age, trestbps, chol)
# (exang _|_ chol | sex, restecg, age, thalach, heartdisease)
# (exang _|_ thalach | sex, restecg, age, heartdisease, chol)
# (exang _|_ chol | sex, restecg, trestbps, thalach, heartdisease)
# (exang _|_ thalach | sex, restecg, trestbps, heartdisease, chol)
# (exang _|_ restecg, chol, heartdisease | sex, fbs, age, trestbps, thalach)
# (exang _|_ restecg, chol, thalach | sex, fbs, age, trestbps, heartdisease)
# (exang _|_ restecg, heartdisease, thalach | sex, fbs, age, trestbps, chol)
# (exang _|_ restecg, chol | sex, fbs, age, thalach, heartdisease)
# (exang _|_ restecg, thalach | sex, fbs, age, heartdisease, chol)
# (exang _|_ restecg, chol | sex, fbs, trestbps, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | sex, fbs, trestbps, thalach, chol)
# (exang _|_ restecg, thalach | sex, fbs, trestbps, heartdisease, chol)
# (exang _|_ restecg | sex, fbs, thalach, heartdisease, chol)
# (exang _|_ restecg, chol, fbs | sex, age, trestbps, thalach, heartdisease)
# (exang _|_ restecg, fbs, heartdisease | sex, age, trestbps, thalach, chol)
# (exang _|_ restecg, fbs, thalach | sex, age, trestbps, heartdisease, chol)
# (exang _|_ restecg | sex, age, thalach, heartdisease, chol)
# (exang _|_ restecg | sex, trestbps, thalach, heartdisease, chol)
# (exang _|_ heartdisease, chol | restecg, fbs, age, trestbps, thalach)
# (exang _|_ chol, thalach | restecg, fbs, age, trestbps, heartdisease)
# (exang _|_ heartdisease, thalach | restecg, fbs, age, trestbps, chol)
# (exang _|_ chol | restecg, fbs, age, thalach, heartdisease)
# (exang _|_ thalach | restecg, fbs, age, heartdisease, chol)
# (exang _|_ chol | restecg, fbs, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease | restecg, fbs, trestbps, thalach, chol)
# (exang _|_ thalach | restecg, fbs, trestbps, heartdisease, chol)
# (exang _|_ chol, fbs | restecg, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, fbs | restecg, age, trestbps, thalach, chol)
# (exang _|_ fbs, thalach | restecg, age, trestbps, heartdisease, chol)
# (exang _|_ restecg, chol | fbs, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, restecg | fbs, age, trestbps, thalach, chol)
# (exang _|_ restecg, thalach | fbs, age, trestbps, heartdisease, chol)
# (exang _|_ restecg | fbs, age, thalach, heartdisease, chol)
# (exang _|_ restecg | fbs, trestbps, thalach, heartdisease, chol)
# (exang _|_ restecg, fbs | age, trestbps, thalach, heartdisease, chol)
# (exang _|_ heartdisease, chol | sex, restecg, fbs, age, trestbps, thalach)
# (exang _|_ chol, thalach | sex, restecg, fbs, age, trestbps, heartdisease)
# (exang _|_ heartdisease, thalach | sex, restecg, fbs, age, trestbps, chol)
# (exang _|_ chol | sex, restecg, fbs, age, thalach, heartdisease)
# (exang _|_ thalach | sex, restecg, fbs, age, heartdisease, chol)
# (exang _|_ chol | sex, restecg, fbs, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease | sex, restecg, fbs, trestbps, thalach, chol)
# (exang _|_ thalach | sex, restecg, fbs, trestbps, heartdisease, chol)
# (exang _|_ chol, fbs | sex, restecg, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease, fbs | sex, restecg, age, trestbps, thalach, chol)
# (exang _|_ fbs, thalach | sex, restecg, age, trestbps, heartdisease, chol)
# (exang _|_ restecg, chol | sex, fbs, age, trestbps, thalach, heartdisease)
# (exang _|_ restecg, heartdisease | sex, fbs, age, trestbps, thalach, chol)
# (exang _|_ restecg, thalach | sex, fbs, age, trestbps, heartdisease, chol)
# (exang _|_ restecg | sex, fbs, age, thalach, heartdisease, chol)
# (exang _|_ restecg | sex, fbs, trestbps, thalach, heartdisease, chol)
# (exang _|_ restecg, fbs | sex, age, trestbps, thalach, heartdisease, chol)
# (exang _|_ chol | restecg, fbs, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease | restecg, fbs, age, trestbps, thalach, chol)
# (exang _|_ thalach | restecg, fbs, age, trestbps, heartdisease, chol)
# (exang _|_ fbs | restecg, age, trestbps, thalach, heartdisease, chol)
# (exang _|_ restecg | fbs, age, trestbps, thalach, heartdisease, chol)
# (exang _|_ chol | sex, restecg, fbs, age, trestbps, thalach, heartdisease)
# (exang _|_ heartdisease | sex, restecg, fbs, age, trestbps, thalach, chol)
# (exang _|_ thalach | sex, restecg, fbs, age, trestbps, heartdisease, chol)
# (exang _|_ fbs | sex, restecg, age, trestbps, thalach, heartdisease, chol)
# (exang _|_ restecg | sex, fbs, age, trestbps, thalach, heartdisease, chol)
# (heartdisease _|_ sex, age, exang | fbs, trestbps)
# (heartdisease _|_ sex, exang | age, trestbps)
# (heartdisease _|_ age, exang | sex, fbs, trestbps)
# (heartdisease _|_ exang | sex, age, trestbps)
# (heartdisease _|_ sex, age, exang | restecg, fbs, trestbps)
# (heartdisease _|_ sex, exang | restecg, age, trestbps)
# (heartdisease _|_ sex, age | fbs, exang, trestbps)
# (heartdisease _|_ sex, exang | fbs, age, trestbps)
# (heartdisease _|_ sex, age, exang | fbs, trestbps, thalach)
# (heartdisease _|_ sex, age, exang | chol, fbs, trestbps)
# (heartdisease _|_ sex | age, exang, trestbps)
# (heartdisease _|_ sex, exang | age, trestbps, thalach)
# (heartdisease _|_ sex, exang | chol, age, trestbps)
# (heartdisease _|_ age, exang | sex, fbs, restecg, trestbps)
# (heartdisease _|_ exang | sex, age, restecg, trestbps)
# (heartdisease _|_ age | sex, fbs, exang, trestbps)
# (heartdisease _|_ exang | sex, fbs, age, trestbps)
# (heartdisease _|_ age, exang | sex, fbs, trestbps, thalach)
# (heartdisease _|_ age, exang | sex, chol, fbs, trestbps)
# (heartdisease _|_ exang | sex, age, trestbps, thalach)
# (heartdisease _|_ exang | sex, chol, age, trestbps)
# (heartdisease _|_ sex, age | restecg, fbs, exang, trestbps)
# (heartdisease _|_ sex, exang | restecg, fbs, age, trestbps)
# (heartdisease _|_ sex, age, exang | restecg, fbs, trestbps, thalach)
# ...
# (thalach _|_ age | sex, fbs, exang, trestbps, chol)
# (thalach _|_ restecg, age, trestbps | sex, fbs, exang, heartdisease, chol)
# (thalach _|_ restecg, chol, exang | sex, fbs, age, trestbps, heartdisease)
# (thalach _|_ exang | sex, fbs, age, trestbps, chol)
# (thalach _|_ restecg, exang, trestbps | sex, fbs, age, heartdisease, chol)
# (thalach _|_ restecg, age, exang | sex, fbs, trestbps, heartdisease, chol)
# (thalach _|_ restecg, chol, fbs | sex, exang, age, trestbps, heartdisease)
# (thalach _|_ restecg, fbs, trestbps | sex, exang, age, heartdisease, chol)
# (thalach _|_ restecg, fbs, age | sex, exang, trestbps, heartdisease, chol)
# (thalach _|_ restecg, fbs, exang | sex, age, trestbps, heartdisease, chol)
# (thalach _|_ sex | restecg, fbs, exang, age, trestbps)
# (thalach _|_ sex, chol, trestbps | restecg, fbs, exang, age, heartdisease)
# (thalach _|_ sex, chol, age | restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ sex, age | restecg, fbs, exang, trestbps, chol)
# (thalach _|_ sex, age, trestbps | restecg, fbs, exang, heartdisease, chol)
# (thalach _|_ sex, chol, exang | restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ sex, exang | restecg, fbs, age, trestbps, chol)
# (thalach _|_ sex, exang, trestbps | restecg, fbs, age, heartdisease, chol)
# (thalach _|_ sex, age, exang | restecg, fbs, trestbps, heartdisease, chol)
# (thalach _|_ sex, chol, fbs | restecg, exang, age, trestbps, heartdisease)
# (thalach _|_ sex | restecg, exang, age, trestbps, chol)
# (thalach _|_ sex, fbs, trestbps | restecg, exang, age, heartdisease, chol)
# (thalach _|_ sex, fbs, age | restecg, exang, trestbps, heartdisease, chol)
# (thalach _|_ sex, fbs, exang | restecg, age, trestbps, heartdisease, chol)
# (thalach _|_ sex, chol, restecg | fbs, exang, age, trestbps, heartdisease)
# (thalach _|_ sex | fbs, exang, age, trestbps, chol)
# (thalach _|_ sex, restecg, trestbps | fbs, exang, age, heartdisease, chol)
# (thalach _|_ sex, age, restecg | fbs, exang, trestbps, heartdisease, chol)
# (thalach _|_ sex, restecg, exang | fbs, age, trestbps, heartdisease, chol)
# (thalach _|_ sex, fbs, restecg | exang, age, trestbps, heartdisease, chol)
# (thalach _|_ chol, trestbps | sex, restecg, fbs, exang, age, heartdisease)
# (thalach _|_ chol, age | sex, restecg, fbs, exang, trestbps, heartdisease)
# (thalach _|_ age | sex, restecg, fbs, exang, trestbps, chol)
# (thalach _|_ age, trestbps | sex, restecg, fbs, exang, heartdisease, chol)
# (thalach _|_ chol, exang | sex, restecg, fbs, age, trestbps, heartdisease)
# (thalach _|_ exang | sex, restecg, fbs, age, trestbps, chol)
# (thalach _|_ exang, trestbps | sex, restecg, fbs, age, heartdisease, chol)
# (thalach _|_ age, exang | sex, restecg, fbs, trestbps, heartdisease, chol)
# (thalach _|_ chol, fbs | sex, restecg, exang, age, trestbps, heartdisease)
# (thalach _|_ fbs, trestbps | sex, restecg, exang, age, heartdisease, chol)
# (thalach _|_ fbs, age | sex, restecg, exang, trestbps, heartdisease, chol)
# (thalach _|_ fbs, exang | sex, restecg, age, trestbps, heartdisease, chol)
# (thalach _|_ restecg, chol | sex, fbs, exang, age, trestbps, heartdisease)
# (thalach _|_ restecg, trestbps | sex, fbs, exang, age, heartdisease, chol)
# (thalach _|_ restecg, age | sex, fbs, exang, trestbps, heartdisease, chol)
# (thalach _|_ restecg, exang | sex, fbs, age, trestbps, heartdisease, chol)
# (thalach _|_ restecg, fbs | sex, exang, age, trestbps, heartdisease, chol)
# (thalach _|_ sex, chol | restecg, fbs, exang, age, trestbps, heartdisease)
# (thalach _|_ sex | restecg, fbs, exang, age, trestbps, chol)
# (thalach _|_ sex, trestbps | restecg, fbs, exang, age, heartdisease, chol)
# (thalach _|_ sex, age | restecg, fbs, exang, trestbps, heartdisease, chol)
# (thalach _|_ sex, exang | restecg, fbs, age, trestbps, heartdisease, chol)
# (thalach _|_ sex, fbs | restecg, exang, age, trestbps, heartdisease, chol)
# (thalach _|_ sex, restecg | fbs, exang, age, trestbps, heartdisease, chol)
# (thalach _|_ chol | sex, restecg, fbs, exang, age, trestbps, heartdisease)
# (thalach _|_ trestbps | sex, restecg, fbs, exang, age, heartdisease, chol)
# (thalach _|_ age | sex, restecg, fbs, exang, trestbps, heartdisease, chol)
# (thalach _|_ exang | sex, restecg, fbs, age, trestbps, heartdisease, chol)
# (thalach _|_ fbs | sex, restecg, exang, age, trestbps, heartdisease, chol)
# (thalach _|_ restecg | sex, fbs, exang, age, trestbps, heartdisease, chol)
# (thalach _|_ sex | restecg, fbs, exang, age, trestbps, heartdisease, chol)
# (chol _|_ sex, restecg, age, trestbps, thalach, fbs, exang | heartdisease)
# (chol _|_ restecg, age, trestbps, thalach, fbs, exang | sex, heartdisease)
# (chol _|_ sex, age, trestbps, thalach, fbs, exang | restecg, heartdisease)
# (chol _|_ sex, age, exang | fbs, trestbps)
# (chol _|_ sex, restecg, age, trestbps, thalach, exang | heartdisease, fbs)
# (chol _|_ sex, restecg, age, trestbps, thalach, fbs | heartdisease, exang)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach, fbs, exang | heartdisease, age)
# (chol _|_ sex, restecg, age, thalach, fbs, exang | heartdisease, trestbps)
# (chol _|_ sex, restecg, age, trestbps, fbs, exang | heartdisease, thalach)
# (chol _|_ age, trestbps, thalach, fbs, exang | sex, heartdisease, restecg)
# (chol _|_ age, exang | sex, fbs, trestbps)
# (chol _|_ restecg, age, trestbps, thalach, exang | sex, fbs, heartdisease)
# (chol _|_ restecg, age, trestbps, thalach, fbs | sex, heartdisease, exang)
# (chol _|_ exang | sex, age, trestbps)
# (chol _|_ restecg, trestbps, thalach, fbs, exang | sex, age, heartdisease)
# (chol _|_ restecg, age, thalach, fbs, exang | sex, heartdisease, trestbps)
# (chol _|_ restecg, age, trestbps, fbs, exang | sex, heartdisease, thalach)
# (chol _|_ sex, age, exang | restecg, fbs, trestbps)
# (chol _|_ sex, age, trestbps, thalach, exang | restecg, fbs, heartdisease)
# (chol _|_ sex, age, trestbps, thalach, fbs | restecg, heartdisease, exang)
# (chol _|_ sex, exang | restecg, age, trestbps)
# (chol _|_ sex, trestbps, thalach, fbs, exang | restecg, age, heartdisease)
# (chol _|_ sex, age, thalach, fbs, exang | restecg, heartdisease, trestbps)
# (chol _|_ sex, age, trestbps, fbs, exang | restecg, heartdisease, thalach)
# (chol _|_ sex, age | fbs, exang, trestbps)
# (chol _|_ sex, restecg, age, trestbps, thalach | heartdisease, fbs, exang)
# (chol _|_ sex, exang | fbs, age, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach, exang | heartdisease, fbs, age)
# (chol _|_ sex, age, exang | fbs, trestbps, thalach)
# (chol _|_ sex, restecg, age, thalach, exang | heartdisease, fbs, trestbps)
# (chol _|_ sex, restecg, age, trestbps, exang | heartdisease, fbs, thalach)
# (chol _|_ sex | age, exang, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach, fbs | heartdisease, age, exang)
# (chol _|_ sex, restecg, age, thalach, fbs | heartdisease, exang, trestbps)
# (chol _|_ sex, restecg, age, trestbps, fbs | heartdisease, exang, thalach)
# (chol _|_ sex, exang | age, trestbps, thalach)
# (chol _|_ sex, restecg, thalach, fbs, exang | heartdisease, age, trestbps)
# (chol _|_ sex, restecg, trestbps, fbs, exang | heartdisease, age, thalach)
# (chol _|_ sex, restecg, age, fbs, exang | heartdisease, trestbps, thalach)
# (chol _|_ age, exang | sex, fbs, restecg, trestbps)
# (chol _|_ age, exang, trestbps, thalach | sex, fbs, heartdisease, restecg)
# (chol _|_ fbs, age, trestbps, thalach | sex, heartdisease, restecg, exang)
# (chol _|_ exang | sex, age, restecg, trestbps)
# (chol _|_ fbs, exang, trestbps, thalach | sex, age, heartdisease, restecg)
# (chol _|_ fbs, age, exang, thalach | sex, heartdisease, restecg, trestbps)
# (chol _|_ fbs, trestbps, age, exang | sex, heartdisease, restecg, thalach)
# (chol _|_ age | sex, fbs, exang, trestbps)
# (chol _|_ restecg, age, trestbps, thalach | sex, fbs, heartdisease, exang)
# (chol _|_ exang | sex, fbs, age, trestbps)
# (chol _|_ restecg, exang, trestbps, thalach | sex, fbs, heartdisease, age)
# (chol _|_ age, exang | sex, fbs, trestbps, thalach)
# (chol _|_ restecg, age, exang, thalach | sex, fbs, heartdisease, trestbps)
# (chol _|_ restecg, age, exang, trestbps | sex, fbs, heartdisease, thalach)
# (chol _|_ restecg, fbs, trestbps, thalach | sex, age, heartdisease, exang)
# (chol _|_ restecg, fbs, age, thalach | sex, heartdisease, exang, trestbps)
# (chol _|_ restecg, fbs, age, trestbps | sex, heartdisease, exang, thalach)
# (chol _|_ exang | sex, age, trestbps, thalach)
# (chol _|_ restecg, fbs, exang, thalach | sex, age, heartdisease, trestbps)
# (chol _|_ restecg, fbs, exang, trestbps | sex, age, heartdisease, thalach)
# (chol _|_ restecg, fbs, age, exang | sex, heartdisease, trestbps, thalach)
# (chol _|_ sex, age | restecg, fbs, exang, trestbps)
# (chol _|_ sex, age, trestbps, thalach | restecg, fbs, heartdisease, exang)
# (chol _|_ sex, exang | restecg, fbs, age, trestbps)
# (chol _|_ sex, exang, trestbps, thalach | restecg, fbs, heartdisease, age)
# (chol _|_ sex, age, exang | restecg, fbs, trestbps, thalach)
# (chol _|_ sex, age, exang, thalach | restecg, fbs, heartdisease, trestbps)
# (chol _|_ sex, age, exang, trestbps | restecg, fbs, heartdisease, thalach)
# (chol _|_ sex | restecg, age, exang, trestbps)
# (chol _|_ sex, fbs, trestbps, thalach | restecg, age, heartdisease, exang)
# (chol _|_ sex, fbs, age, thalach | restecg, heartdisease, exang, trestbps)
# (chol _|_ sex, fbs, age, trestbps | restecg, heartdisease, exang, thalach)
# (chol _|_ sex, exang | restecg, age, trestbps, thalach)
# (chol _|_ sex, fbs, exang, thalach | restecg, age, heartdisease, trestbps)
# (chol _|_ sex, fbs, exang, trestbps | restecg, age, heartdisease, thalach)
# (chol _|_ sex, fbs, age, exang | restecg, heartdisease, trestbps, thalach)
# (chol _|_ sex | fbs, age, exang, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach | heartdisease, fbs, age, exang)
# (chol _|_ sex, age | fbs, exang, trestbps, thalach)
# (chol _|_ sex, age, restecg, thalach | heartdisease, fbs, exang, trestbps)
# (chol _|_ sex, age, restecg, trestbps | heartdisease, fbs, exang, thalach)
# (chol _|_ sex, exang | fbs, age, trestbps, thalach)
# (chol _|_ sex, restecg, exang, thalach | heartdisease, fbs, age, trestbps)
# (chol _|_ sex, restecg, trestbps, exang | heartdisease, fbs, age, thalach)
# (chol _|_ sex, age, restecg, exang | heartdisease, fbs, trestbps, thalach)
# (chol _|_ sex | age, exang, trestbps, thalach)
# (chol _|_ sex, fbs, restecg, thalach | heartdisease, age, exang, trestbps)
# (chol _|_ sex, fbs, restecg, trestbps | heartdisease, age, exang, thalach)
# (chol _|_ sex, fbs, age, restecg | heartdisease, exang, trestbps, thalach)
# (chol _|_ sex, fbs, restecg, exang | heartdisease, age, trestbps, thalach)
# (chol _|_ age | sex, restecg, fbs, exang, trestbps)
# (chol _|_ age, trestbps, thalach | sex, restecg, fbs, exang, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, age, trestbps)
# (chol _|_ exang, trestbps, thalach | sex, restecg, fbs, age, heartdisease)
# (chol _|_ age, exang | sex, restecg, fbs, trestbps, thalach)
# (chol _|_ age, exang, thalach | sex, restecg, fbs, trestbps, heartdisease)
# (chol _|_ age, exang, trestbps | sex, restecg, fbs, thalach, heartdisease)
# (chol _|_ fbs, trestbps, thalach | sex, restecg, exang, age, heartdisease)
# (chol _|_ fbs, age, thalach | sex, restecg, exang, trestbps, heartdisease)
# (chol _|_ fbs, age, trestbps | sex, restecg, exang, thalach, heartdisease)
# (chol _|_ exang | sex, restecg, age, trestbps, thalach)
# (chol _|_ fbs, exang, thalach | sex, restecg, age, trestbps, heartdisease)
# (chol _|_ fbs, exang, trestbps | sex, restecg, age, thalach, heartdisease)
# (chol _|_ fbs, age, exang | sex, restecg, trestbps, thalach, heartdisease)
# (chol _|_ restecg, trestbps, thalach | sex, fbs, exang, age, heartdisease)
# (chol _|_ age | sex, fbs, exang, trestbps, thalach)
# (chol _|_ restecg, age, thalach | sex, fbs, exang, trestbps, heartdisease)
# (chol _|_ restecg, age, trestbps | sex, fbs, exang, thalach, heartdisease)
# (chol _|_ exang | sex, fbs, age, trestbps, thalach)
# (chol _|_ restecg, exang, thalach | sex, fbs, age, trestbps, heartdisease)
# (chol _|_ restecg, exang, trestbps | sex, fbs, age, thalach, heartdisease)
# (chol _|_ restecg, age, exang | sex, fbs, trestbps, thalach, heartdisease)
# (chol _|_ restecg, fbs, thalach | sex, exang, age, trestbps, heartdisease)
# (chol _|_ restecg, fbs, trestbps | sex, exang, age, thalach, heartdisease)
# (chol _|_ restecg, fbs, age | sex, exang, trestbps, thalach, heartdisease)
# (chol _|_ restecg, fbs, exang | sex, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | restecg, fbs, exang, age, trestbps)
# (chol _|_ sex, trestbps, thalach | restecg, fbs, exang, age, heartdisease)
# (chol _|_ sex, age | restecg, fbs, exang, trestbps, thalach)
# (chol _|_ sex, age, thalach | restecg, fbs, exang, trestbps, heartdisease)
# (chol _|_ sex, age, trestbps | restecg, fbs, exang, thalach, heartdisease)
# (chol _|_ sex, exang | restecg, fbs, age, trestbps, thalach)
# (chol _|_ sex, exang, thalach | restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ sex, exang, trestbps | restecg, fbs, age, thalach, heartdisease)
# (chol _|_ sex, age, exang | restecg, fbs, trestbps, thalach, heartdisease)
# (chol _|_ sex | restecg, exang, age, trestbps, thalach)
# (chol _|_ sex, fbs, thalach | restecg, exang, age, trestbps, heartdisease)
# (chol _|_ sex, fbs, trestbps | restecg, exang, age, thalach, heartdisease)
# (chol _|_ sex, fbs, age | restecg, exang, trestbps, thalach, heartdisease)
# (chol _|_ sex, fbs, exang | restecg, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | fbs, exang, age, trestbps, thalach)
# (chol _|_ sex, restecg, thalach | fbs, exang, age, trestbps, heartdisease)
# (chol _|_ sex, restecg, trestbps | fbs, exang, age, thalach, heartdisease)
# (chol _|_ sex, age, restecg | fbs, exang, trestbps, thalach, heartdisease)
# (chol _|_ sex, restecg, exang | fbs, age, trestbps, thalach, heartdisease)
# (chol _|_ sex, fbs, restecg | exang, age, trestbps, thalach, heartdisease)
# (chol _|_ trestbps, thalach | sex, restecg, fbs, exang, age, heartdisease)
# (chol _|_ age | sex, restecg, fbs, exang, trestbps, thalach)
# (chol _|_ age, thalach | sex, restecg, fbs, exang, trestbps, heartdisease)
# (chol _|_ age, trestbps | sex, restecg, fbs, exang, thalach, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, age, trestbps, thalach)
# (chol _|_ exang, thalach | sex, restecg, fbs, age, trestbps, heartdisease)
# (chol _|_ exang, trestbps | sex, restecg, fbs, age, thalach, heartdisease)
# (chol _|_ age, exang | sex, restecg, fbs, trestbps, thalach, heartdisease)
# (chol _|_ fbs, thalach | sex, restecg, exang, age, trestbps, heartdisease)
# (chol _|_ fbs, trestbps | sex, restecg, exang, age, thalach, heartdisease)
# (chol _|_ fbs, age | sex, restecg, exang, trestbps, thalach, heartdisease)
# (chol _|_ fbs, exang | sex, restecg, age, trestbps, thalach, heartdisease)
# (chol _|_ restecg, thalach | sex, fbs, exang, age, trestbps, heartdisease)
# (chol _|_ restecg, trestbps | sex, fbs, exang, age, thalach, heartdisease)
# (chol _|_ restecg, age | sex, fbs, exang, trestbps, thalach, heartdisease)
# (chol _|_ restecg, exang | sex, fbs, age, trestbps, thalach, heartdisease)
# (chol _|_ restecg, fbs | sex, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | restecg, fbs, exang, age, trestbps, thalach)
# (chol _|_ sex, thalach | restecg, fbs, exang, age, trestbps, heartdisease)
# (chol _|_ sex, trestbps | restecg, fbs, exang, age, thalach, heartdisease)
# (chol _|_ sex, age | restecg, fbs, exang, trestbps, thalach, heartdisease)
# (chol _|_ sex, exang | restecg, fbs, age, trestbps, thalach, heartdisease)
# (chol _|_ sex, fbs | restecg, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ sex, restecg | fbs, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ thalach | sex, restecg, fbs, exang, age, trestbps, heartdisease)
# (chol _|_ trestbps | sex, restecg, fbs, exang, age, thalach, heartdisease)
# (chol _|_ age | sex, restecg, fbs, exang, trestbps, thalach, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, age, trestbps, thalach, heartdisease)
# (chol _|_ fbs | sex, restecg, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ restecg | sex, fbs, exang, age, trestbps, thalach, heartdisease)
# (chol _|_ sex | restecg, fbs, exang, age, trestbps, thalach, heartdisease)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# Computing the probability of bronc given smoke.
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5770 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4230 │
# ╘════════════════╧═════════════════════╛

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.5510 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.4490 │
# ╘════════════════╧═════════════════════╛
